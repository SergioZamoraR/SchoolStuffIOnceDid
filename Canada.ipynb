# %%
import pandas as pd
import numpy as np

# %%
# %ls 'datasets/'
# Out:
# adult.csv                  census.csv            pokemon.csv
# airline_data.csv           cwurData.csv          sample_pivot.csv
# antropometria00.csv        data.csv              tips.csv
# antropometria-dataset.csv  headbrain.csv         weight-height.csv
# Canada.xlsx                movies.csv
# Cartwheeldata.csv          nhanes_2015_2016.csv

# %%
df=pd.read_excel('datasets/Canada.xlsx',
                 Sheetname = 'Canada by Citizenship',
                 skiprows=range(20),
                 skipfooter=2,
                engine= 'openpyxl')
df
# Out:
#           Type    Coverage                               AreaName  \
# 0   Immigrants    Citizens                       Northern America
# 1   Immigrants  Foreigners                                 Africa
# 2   Immigrants  Foreigners                                 Africa
# 3   Immigrants  Foreigners                                 Africa
# 4   Immigrants  Foreigners                                 Africa
# 5   Immigrants  Foreigners                                 Africa
# 6   Immigrants  Foreigners                           Africa Total
# 7   Immigrants  Foreigners                                   Asia
# 8   Immigrants  Foreigners                                   Asia
# 9   Immigrants  Foreigners                                   Asia
# 10  Immigrants  Foreigners                                   Asia
# 11  Immigrants  Foreigners                                   Asia
# 12  Immigrants  Foreigners                             Asia Total
# ...

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Columns: 39 entries, Type to Unnamed: 38
# dtypes: float64(6), object(33)
# memory usage: 13.2+ KB

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',    'AreaName',     'RegName',
#                 1980,          1981,          1982,          1983,
#                 1984,          1985,          1986,          1987,
#                 1988,          1989,          1990,          1991,
#                 1992,          1993,          1994,          1995,
#                 1996,          1997,          1998,          1999,
#                 2000,          2001,          2002,          2003,
#                 2004,          2005,          2006,          2007,
#                 2008,          2009,          2010,          2011,
#                 2012,          2013, 'Unnamed: 38'],
#       dtype='object')

# %%
df.drop(['Type', 'Coverage'], axis=1, inplace=True)
df.columns
# Out:
# Index([   'AreaName',     'RegName',          1980,          1981,
#                 1982,          1983,          1984,          1985,
#                 1986,          1987,          1988,          1989,
#                 1990,          1991,          1992,          1993,
#                 1994,          1995,          1996,          1997,
#                 1998,          1999,          2000,          2001,
#                 2002,          2003,          2004,          2005,
#                 2006,          2007,          2008,          2009,
#                 2010,          2011,          2012,          2013,
#        'Unnamed: 38'],
#       dtype='object')

# %%
df.rename(columns= {'AreaName': 'Continent',
                   'RegName': 'Region'},
                inplace=True)
df.columns
# Out:
# Index([  'Continent',      'Region',          1980,          1981,
#                 1982,          1983,          1984,          1985,
#                 1986,          1987,          1988,          1989,
#                 1990,          1991,          1992,          1993,
#                 1994,          1995,          1996,          1997,
#                 1998,          1999,          2000,          2001,
#                 2002,          2003,          2004,          2005,
#                 2006,          2007,          2008,          2009,
#                 2010,          2011,          2012,          2013,
#        'Unnamed: 38'],
#       dtype='object')

# %%
df['Total']=df.iloc[:,4:].sum(axis=1)
df.head(2)
# Out:
#           Continent            Region  1980  1981  1982  1983  1984  1985  \
# 0  Northern America  Northern America    ..    ..    ..    ..    ..    ..
# 1            Africa    Eastern Africa  1471  1641  1426  1094  1187  1134
#
#    1986  1987  ...  2006  2007  2008  2009  2010  2011    2012  2013  \
# 0    ..    ..  ...    ..    ..    ..    ..    ..     1     1.0   NaN
# 1  1454  2734  ...  6750  6669  6705  6922  8591  8956  8846.0   NaN
#
#    Unnamed: 38    Total
# 0          NaN      6.0
# 1          NaN  24717.0
#
# [2 rows x 38 columns]

# %%
df.describe()
# Out:
#                1993          1995           1996           2012  2013  \
# count     29.000000     29.000000      29.000000      29.000000   0.0
# mean   16249.965517  13644.310345   14504.827586   17456.310345   NaN
# std    22164.376752  19938.986287   22244.386514   30018.783873   NaN
# min        1.000000      1.000000       1.000000       1.000000   NaN
# 25%     1567.000000   1474.000000    1324.000000    1679.000000   NaN
# 50%     7435.000000   6158.000000    5962.000000    7891.000000   NaN
# 75%    16569.000000  18726.000000   17844.000000   15453.000000   NaN
# max    98737.000000  90424.000000  103030.000000  152218.000000   NaN
#
#        Unnamed: 38          Total
# count          0.0      43.000000
# mean           NaN   41716.441860
# std            NaN   80222.187483
# min            NaN       0.000000
# 25%            NaN       0.000000
# 50%            NaN    6918.000000
# 75%            NaN   46509.500000
# max            NaN  444409.000000

# %%
df.columns
# Out:
# Index([  'Continent',      'Region',          1980,          1981,
#                 1982,          1983,          1984,          1985,
#                 1986,          1987,          1988,          1989,
#                 1990,          1991,          1992,          1993,
#                 1994,          1995,          1996,          1997,
#                 1998,          1999,          2000,          2001,
#                 2002,          2003,          2004,          2005,
#                 2006,          2007,          2008,          2009,
#                 2010,          2011,          2012,          2013,
#        'Unnamed: 38',       'Total'],
#       dtype='object')

# %%
df.drop(['Unnamed: 38'], axis=1, inplace=True)
df.columns
# Out:
# Index(['Continent',    'Region',        1980,        1981,        1982,
#               1983,        1984,        1985,        1986,        1987,
#               1988,        1989,        1990,        1991,        1992,
#               1993,        1994,        1995,        1996,        1997,
#               1998,        1999,        2000,        2001,        2002,
#               2003,        2004,        2005,        2006,        2007,
#               2008,        2009,        2010,        2011,        2012,
#               2013,     'Total'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Continent',    'Region',        1980,        1981,        1982,
#               1983,        1984,        1985,        1986,        1987,
#               1988,        1989,        1990,        1991,        1992,
#               1993,        1994,        1995,        1996,        1997,
#               1998,        1999,        2000,        2001,        2002,
#               2003,        2004,        2005,        2006,        2007,
#               2008,        2009,        2010,        2011,        2012,
#               2013,     'Total'],
#       dtype='object')

# %%
df.loc['Japan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Japan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_156/541448290.py in <module>
# ----> 1 df.loc['Japan']
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
# ...
