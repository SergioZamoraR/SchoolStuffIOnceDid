# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# %ls 'datasets/'
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   Pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       Untitled.ipynb
# Cartwheeldata.csv          movies.csv     weight-height.csv

# %%
df=pd.read_csv('datasets/antropometria-dataset.csv')
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(data=df.loc[:,'cintura'])

# %%
pivot1=pd.pivot_table(df,
               index='desc_ent',
                       columns='sexo',
                       values='peso',
                       aggfunc='median')
pivot1
# Out:
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# NAYARIT                          69.0500  63.7000
# ...

# %%
sns.boxplot(data=pivot1)

# %%
pivot2=pd.pivot_table(df,
               index='desc_ent',
                       columns='sexo',
                       values='cadera')
pivot2
# Out:
# sexo                                     1           2
# desc_ent
# AGUASCALIENTES                   95.384768   99.632282
# BAJA CALIFORNIA                  98.499394  101.438643
# BAJA CALIFORNIA SUR              99.918812  102.727888
# CAMPECHE                         96.502321  100.843431
# CHIAPAS                          89.872177   95.798701
# CHIHUAHUA                        96.642642  102.619935
# COAHUILA DE ZARAGOZA             96.150167  103.199670
# COLIMA                           97.162548  102.786677
# DISTRITO FEDERAL                 96.531034  104.390744
# DURANGO                          95.526667  100.465287
# GUANAJUATO                       93.238103  100.542946
# GUERRERO                         91.349440   96.751029
# HIDALGO                          92.186387   97.210698
# JALISCO                          96.254027  102.971486
# MEXICO                           93.984817   96.991339
# MICHOACAN DE OCAMPO              93.929651  100.008339
# ...

# %%
sns.lineplot(data=pivot2)

# %%
pivot3=pd.pivot_table(df,
               index='desc_ent',
                       columns='sexo',
                       values='sistol',
                       aggfunc='sum')
pivot3
# Out:
# sexo                                    1         2
# desc_ent
# AGUASCALIENTES                   37608.00  42565.25
# BAJA CALIFORNIA                  32240.00  35515.50
# BAJA CALIFORNIA SUR              32076.00  31207.00
# CAMPECHE                         28854.50  35136.25
# CHIAPAS                          28550.00  40385.50
# CHIHUAHUA                        32073.75  37742.75
# COAHUILA DE ZARAGOZA             36171.25  36969.25
# COLIMA                           30854.75  38381.25
# DISTRITO FEDERAL                 20036.00  24548.25
# DURANGO                          31436.75  39155.50
# GUANAJUATO                       34864.00  44234.50
# GUERRERO                         31312.00  43056.75
# HIDALGO                          22626.00  38481.25
# JALISCO                          26649.25  36332.25
# MEXICO                           21846.75  29587.00
# MICHOACAN DE OCAMPO              31250.25  40552.75
# MORELOS                          24613.25  39654.75
# ...

# %%
#try1

# %%
sistol=pivot3.sort_values(by=[1],
                            ascending=False,
                            axis=0
                           )
sistolbien=sistol.head(10)
sistolbien.sort_values(by=[2],
                            ascending=False,
                            axis=0
                           ).plot(kind='barh')

# %%
pivot5=pd.pivot_table(df,
               index='folio',
                     values='cintura')
pivot5
# Out:
#         cintura
# folio
# 10001      82.1
# 10011      78.4
# 10015     111.0
# 10021      73.1
# 10034      71.9
# ...         ...
# 321838     69.8
# 321844     83.6
# 321849    105.0
# 321857    111.8
# 321861     84.3
#
# [17979 rows x 1 columns]

# %%
sns.distplot(df.cintura,
           bins=25,
            kde=False)
