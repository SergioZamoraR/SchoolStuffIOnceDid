# %%
# %ls
# Out:
# 07_02_pie_box_scatter_bubble.ipynb  README.md         session_01/
# Canada.xlsx                         requierementsEXL  Untitled1.ipynb
# datasets/                           requirements.txt  Untitled.ipynb
# nhanes_2015_2016.csv                runtime.txt       welcome_binder.ipynb

# %%
import panda as pd
import numy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_79/3319018137.py in <module>
# ----> 1 import panda as pd
#       2 import numy as np
#
# ModuleNotFoundError: No module named 'panda'

# %%
import panda as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_79/1724862564.py in <module>
# ----> 1 import panda as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
import numy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_79/4106783680.py in <module>
#       1 import pandas as pd
# ----> 2 import numy as np
#
# ModuleNotFoundError: No module named 'numy'

# %%
import pandas as pd
import numpy as np

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv            pokemon.csv
# airline_data.csv           cwurData.csv          sample_pivot.csv
# antropometria00.csv        data.csv              tips.csv
# antropometria-dataset.csv  headbrain.csv         weight-height.csv
# Canada.xlsx                movies.csv
# Cartwheeldata.csv          nhanes_2015_2016.csv

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df.head
# Out:
# <bound method NDFrame.head of     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %% [markdown]
# La variable
#     'Age' representa la edad de la persona, tipo de dato 'Numerica': Enteros
#     'Gender' representa el genero de la persona tipo de dato 'Categrica':

# %%
dist=df[['CWDistance']]
dist
type (dist)
# Out:
# pandas.core.frame.DataFrame

# %%
dist
# Out:
#     CWDistance
# 0           79
# 1           70
# 2           85
# 3           87
# 4           72
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96
# 11          79
# 12          92
# 13          66
# 14          72
# 15         115
# 16          90
# 17          74
# 18          64
# 19          85
# 20          66
# 21         101
# 22          82
# 23          63
# 24          67

# %%
type(dist)
# Out:
# pandas.core.frame.DataFrame

# %%
colnames=list(df.columns)
colnames
# Out:
# ['ID',
#  'Age',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'Wingspan',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Score']

# %%
type(colnames)
# Out:
# list

# %%
colnames.sort()

# %%
colnames
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
for i in df.columns
    print (i)
# Out:
#   File "/tmp/ipykernel_79/1884754706.py", line 1
#     for i in df.columns
#                        ^
# SyntaxError: invalid syntax

# %%
df.iloc[1:5,2:7]
# Out:
#   Gender  GenderGroup Glasses  GlassesGroup  Height
# 1      F            1       Y             1    62.0
# 2      F            1       Y             1    66.0
# 3      F            1       N             0    64.0
# 4      M            2       N             0    73.0

# %%
df.head(6)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
# 5   6   24      M            2       N             0    75.0      71.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4
# 5          81        N              0      3

# %%
df.iloc[[1,2,3,5,7],2:7]
# Out:
#   Gender  GenderGroup Glasses  GlassesGroup  Height
# 1      F            1       Y             1    62.0
# 2      F            1       Y             1    66.0
# 3      F            1       N             0    64.0
# 5      M            2       N             0    75.0
# 7      F            1       N             0    65.0

# %%
df.loc[0:3, ['Age', 'Gender', 'GenderGroup']]
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1
# 2   33      F            1
# 3   39      F            1

# %% [markdown]
# iloc, usa indices, primero filas y despues columnas
# loc usa los nombres, primer fils y despues columnas

# %%
df.tail(7)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 18  19   23      M            2       Y             1    70.0      69.0
# 19  20   24      F            1       Y             1    68.0      66.0
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 18          64        Y              1      3
# 19          85        Y              1      8
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
df.iloc[:,-1:]
# Out:
#     Score
# 0       7
# 1       8
# 2       7
# 3      10
# 4       4
# 5       3
# 6      10
# 7       9
# 8       5
# 9       8
# 10      6
# 11     10
# 12      6
# 13      4
# 14      9
# 15      6
# 16     10
# 17      5
# 18      3
# 19      8
# 20      2
# 21      8
# 22      4
# 23      5
# 24      3

# %%
df.loc[:,'Score']
# Out:
# 0      7
# 1      8
# 2      7
# 3     10
# 4      4
# 5      3
# 6     10
# 7      9
# 8      5
# 9      8
# 10     6
# 11    10
# 12     6
# 13     4
# 14     9
# 15     6
# 16    10
# 17     5
# 18     3
# 19     8
# 20     2
# 21     8
# 22     4
# 23     5
# 24     3
# Name: Score, dtype: int64

# %%
df.shape
# Out:
# (25, 12)

# %%
df.iloc[:,9:12]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.iloc[:,-3:]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.Age.unique()
# Out:
# array([56, 26, 33, 39, 27, 24, 28, 22, 29, 30, 25, 23, 31])

# %%
df.groupby(['Gender', 'GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64

# %%
df.drop(['Complete','CompleteGroup'],
        inplace = True,
        axis = 1
       )
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_79/3695954628.py in <module>
# ----> 1 df.drop(['Complete','CompleteGroup'],
#       2         inplace = True,
#       3         axis = 1
#       4        )
#       5 df
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance  Score
# 0          79      7
# 1          70      8
# 2          85      7
# 3          87     10
# 4          72      4
