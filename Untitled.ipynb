# %%
print('Hello world')
# Out:
# Hello world

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type (4.0)
# Out:
# float

# %%
math.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_60/114675448.py in <module>
# ----> 1 math.py
#
# AttributeError: module 'math' has no attribute 'py'

# %%
math .py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_60/2148683434.py in <module>
# ----> 1 math .py
#
# AttributeError: module 'math' has no attribute 'py'

# %%
math .pi
# Out:
# 3.141592653589793

# %%
type(nombre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_60/3120047230.py in <module>
# ----> 1 type(nombre)
#
# NameError: name 'nombre' is not defined

# %%
type(True)
# Out:
# bool

# %%
type(-3)
# Out:
# int

# %%
type(2/3)
# Out:
# float

# %%
numbers=[1 2 3 4 5]
# Out:
#   File "/tmp/ipykernel_60/1608677502.py", line 1
#     numbers=[1 2 3 4 5]
#                ^
# SyntaxError: invalid syntax

# %%
numbers=[1,2,3,4,5]

# %%
suma=sum(numbers)

# %%
suma
# Out:
# 15

# %%
lenght=len(numbers)

# %%
lenght
# Out:
# 5

# %%
promedio=suma/lenght

# %%
promedio
# Out:
# 3.0

# %%
a_list=[True,6>5,1==2,None is None,2, 'name', 4.0,3/4]

# %%
a_list
# Out:
# [True, True, False, True, 2, 'name', 4.0, 0.75]

# %%
x=5
y=6
if x<y:
    print ('Es mayor que, muy adecuado'.format(x,y))
else:
        print('Es menor que, inadecuado'.format(x,y))
# Out:
# Es mayor que, muy adecuado
