# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
df=pd.read_csv('datasets/antropometria-dataset.csv')
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
histogram_cintura=df['cintura'].plot(kind='hist',
                                     bins=15
                                    )

# %%
sns.lmplot(x='peso',
           y='cintura',
           data=df,
            fit_reg=False,
           hue='sexo'
          )

# %%
sns.boxplot(data=df.loc[df['sexo']==2,
                         ['cintura']])
plt.title('Cintura mujer')
# Out:
# Text(0.5, 1.0, 'Cintura mujer')

# %%
df.loc[df['sexo']==2]
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 4      210939     3       21                           PUEBLA     2    19
# 6      211879     2       21                           PUEBLA     2    10
# ...       ...   ...      ...                              ...   ...   ...
# 18633  160939     1       16              MICHOACAN DE OCAMPO     2    58
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
sns.lmplot(x='sistol',
           y='diastol',
           data=df.loc[df['sexo']==1,
                         ['sistol', 'diastol']],
            fit_reg=False
          )

# %%
x=df.loc[df['sexo']==1,
                         ['sistol']]
x
# Out:
#        sistol
# 3       71.00
# 5       73.00
# 9       76.50
# 17      78.75
# 21      79.50
# ...       ...
# 18626  209.00
# 18627  209.00
# 18630  210.00
# 18634  216.50
# 18637  230.00
#
# [8154 rows x 1 columns]

# %%
y=df.loc[df['sexo']==1,
                         ['diastol']]
y
# Out:
#        diastol
# 3        64.00
# 5        50.75
# 9        55.50
# 17       60.75
# 21       55.00
# ...        ...
# 18626    95.25
# 18627   110.00
# 18630   140.00
# 18634   107.75
# 18637    66.00
#
# [8154 rows x 1 columns]

# %%
sns.distplot(df.loc[df['sexo']==1,
                         ['cintura']]
            )

# %%
cintura=df.loc[df['sexo']==1,
                         ['cintura']]
cintura
# Out:
#        cintura
# 3        60.60
# 5        59.50
# 9        79.65
# 17       60.70
# 21       96.20
# ...        ...
# 18626   104.25
# 18627   100.75
# 18630    83.60
# 18634   132.00
# 18637    71.35
#
# [8154 rows x 1 columns]

# %%
histogram_cintura=cintura.plot(kind='hist',
                              bins=20
                              )
